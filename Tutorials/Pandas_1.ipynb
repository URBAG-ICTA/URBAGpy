# %% [markdown]
# <h2>Basic data exploration</h2>

# %%
import pandas as pd

# %%
D5 = pd.read_excel('../Data/Dades_4298_D5_10.xlsx')

# %%
D5
# Out:
#       D5'                DATA     T  HR  PPT  RS      P  VV10   DV10  VVX10  \
# 0      D5 2018-01-01 00:00:00  10.2  63  0.0   0  969.3   3.5  349.0   13.2
# 1      D5 2018-01-01 00:30:00   8.7  63  0.0   0  969.7   3.7  313.0   11.0
# 2      D5 2018-01-01 01:00:00   7.7  64  0.0   0  970.3   4.0  293.0   14.2
# 3      D5 2018-01-01 01:30:00   7.4  64  0.0   0  971.1   4.2  295.0   10.6
# 4      D5 2018-01-01 02:00:00   7.3  65  0.0   0  971.7   5.1  293.0   13.1
# ...    ..                 ...   ...  ..  ...  ..    ...   ...    ...    ...
# 35035  D5 2019-12-31 21:30:00   6.5  78  0.0   0  982.1   8.6  313.0   10.9
# 35036  D5 2019-12-31 22:00:00   7.2  76  0.0   0  982.1   3.1  338.0    8.2
# 35037  D5 2019-12-31 22:30:00   6.2  77  0.0   0  982.1   6.6  315.0    9.9
# 35038  D5 2019-12-31 23:00:00   5.5  80  0.0   0  981.8   6.2  314.0   10.4
# 35039  D5 2019-12-31 23:30:00   5.6  79  0.0   0  981.6   7.0  316.0   10.3
#
# ...

# %%
D5.shape
# Out:
# (35040, 22)

# %%
D5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 22 columns):
# D5'       35040 non-null object
# DATA      35040 non-null datetime64[ns]
# T         35040 non-null float64
# HR        35040 non-null int64
# PPT       35040 non-null float64
# RS        35040 non-null int64
# P         35040 non-null float64
# VV10      35029 non-null float64
# DV10      35029 non-null float64
# VVX10     35028 non-null float64
# DVVX10    35028 non-null float64
# VV6       0 non-null float64
# DV6       0 non-null float64
# VVX6      0 non-null float64
# DVVX6     0 non-null float64
# PX        35040 non-null float64
# PN        35040 non-null float64
# HRX       35040 non-null int64
# HRN       35040 non-null int64
# TX        35040 non-null float64
# TN        35040 non-null float64
# SH'       35040 non-null object
# dtypes: datetime64[ns](1), float64(15), int64(4), object(2)
# memory usage: 5.9+ MB

# %%
D5.mean()
# Out:
# T          15.565594
# HR         69.364412
# PPT         0.045385
# RS        183.643950
# P         967.903639
# VV10        4.182129
# DV10      200.763282
# VVX10       6.788989
# DVVX10    203.204608
# VV6              NaN
# DV6              NaN
# VVX6             NaN
# DVVX6            NaN
# PX        968.064683
# PN        967.740842
# HRX        71.364954
# HRN        67.298174
# TX         15.855437
# TN         15.283596
# dtype: float64

# %%
D5.head()
# Out:
#   D5'                DATA     T  HR  PPT  RS      P  VV10   DV10  VVX10  ...  \
# 0  D5 2018-01-01 00:00:00  10.2  63  0.0   0  969.3   3.5  349.0   13.2  ...
# 1  D5 2018-01-01 00:30:00   8.7  63  0.0   0  969.7   3.7  313.0   11.0  ...
# 2  D5 2018-01-01 01:00:00   7.7  64  0.0   0  970.3   4.0  293.0   14.2  ...
# 3  D5 2018-01-01 01:30:00   7.4  64  0.0   0  971.1   4.2  295.0   10.6  ...
# 4  D5 2018-01-01 02:00:00   7.3  65  0.0   0  971.7   5.1  293.0   13.1  ...
#
#    DV6  VVX6  DVVX6     PX     PN  HRX  HRN    TX   TN  SH'
# 0  NaN   NaN    NaN  969.8  968.8   65   62  10.6  9.4   SH
# 1  NaN   NaN    NaN  970.3  968.9   63   62   9.4  8.1   SH
# 2  NaN   NaN    NaN  970.7  969.8   64   63   8.1  7.5   SH
# 3  NaN   NaN    NaN  971.7  970.5   65   64   7.5  7.3   SH
# 4  NaN   NaN    NaN  972.1  971.2   65   64   7.4  7.1   SH
#
# [5 rows x 22 columns]

# %%
D5.head(10)
# Out:
#   D5'                DATA     T  HR  PPT  RS      P  VV10   DV10  VVX10  ...  \
# 0  D5 2018-01-01 00:00:00  10.2  63  0.0   0  969.3   3.5  349.0   13.2  ...
# 1  D5 2018-01-01 00:30:00   8.7  63  0.0   0  969.7   3.7  313.0   11.0  ...
# 2  D5 2018-01-01 01:00:00   7.7  64  0.0   0  970.3   4.0  293.0   14.2  ...
# 3  D5 2018-01-01 01:30:00   7.4  64  0.0   0  971.1   4.2  295.0   10.6  ...
# 4  D5 2018-01-01 02:00:00   7.3  65  0.0   0  971.7   5.1  293.0   13.1  ...
# 5  D5 2018-01-01 02:30:00   6.9  65  0.0   0  971.9   3.3  303.0   10.8  ...
# 6  D5 2018-01-01 03:00:00   6.7  65  0.0   0  972.4   3.8  316.0   11.5  ...
# 7  D5 2018-01-01 03:30:00   6.6  64  0.0   0  972.8   4.3  285.0   12.6  ...
# 8  D5 2018-01-01 04:00:00   6.6  63  0.0   0  973.2   3.5  278.0   11.6  ...
# 9  D5 2018-01-01 04:30:00   6.7  62  0.0   0  973.4   3.7  281.0   11.3  ...
#
#    DV6  VVX6  DVVX6     PX     PN  HRX  HRN    TX   TN  SH'
# 0  NaN   NaN    NaN  969.8  968.8   65   62  10.6  9.4   SH
# ...

# %%
D5.tail()
# Out:
#       D5'                DATA    T  HR  PPT  RS      P  VV10   DV10  VVX10  \
# 35035  D5 2019-12-31 21:30:00  6.5  78  0.0   0  982.1   8.6  313.0   10.9
# 35036  D5 2019-12-31 22:00:00  7.2  76  0.0   0  982.1   3.1  338.0    8.2
# 35037  D5 2019-12-31 22:30:00  6.2  77  0.0   0  982.1   6.6  315.0    9.9
# 35038  D5 2019-12-31 23:00:00  5.5  80  0.0   0  981.8   6.2  314.0   10.4
# 35039  D5 2019-12-31 23:30:00  5.6  79  0.0   0  981.6   7.0  316.0   10.3
#
#        ...  DV6  VVX6  DVVX6     PX     PN  HRX  HRN   TX   TN  SH'
# 35035  ...  NaN   NaN    NaN  982.2  982.0   79   75  7.0  6.2   SH
# 35036  ...  NaN   NaN    NaN  982.3  982.1   77   75  7.6  7.0   SH
# 35037  ...  NaN   NaN    NaN  982.2  981.9   80   74  7.1  5.6   SH
# 35038  ...  NaN   NaN    NaN  982.1  981.6   81   79  5.8  5.3   SH
# 35039  ...  NaN   NaN    NaN  981.8  981.4   81   78  5.8  5.4   SH
#
# [5 rows x 22 columns]

# %%
D5.sample(10)
# Out:
#       D5'                DATA     T  HR  PPT   RS      P  VV10   DV10  VVX10  \
# 32118  D5 2019-11-01 03:00:00  15.3  71  0.0    0  970.0   6.1  349.0    7.4
# 8843   D5 2018-07-04 05:30:00  21.5  68  0.0  178  968.5   0.5  184.0    1.5
# 12798  D5 2018-09-24 15:00:00  22.0  79  0.0  124  973.3   3.8  186.0    6.5
# 14347  D5 2018-10-26 21:30:00  15.7  94  0.0    0  962.5   3.4  327.0    5.2
# 12547  D5 2018-09-19 09:30:00  24.6  69  0.0  663  974.0   1.1   98.0    3.4
# 28696  D5 2019-08-21 20:00:00  21.2  87  0.0    0  972.6   2.0  240.0    3.4
# 7127   D5 2018-05-29 11:30:00  21.6  66  0.0  748  967.1   7.0  212.0   10.8
# 4902   D5 2018-04-13 03:00:00   9.6  98  0.0    0  956.7   2.2   78.0    3.4
# 869    D5 2018-01-19 02:30:00   9.1  59  0.0    0  969.3   3.9  358.0    5.8
# 15633  D5 2018-11-22 16:30:00  12.7  55  0.0    0  967.7   3.2  303.0    3.7
#
#        ...  DV6  VVX6  DVVX6     PX     PN  HRX  HRN    TX    TN  SH'
# ...

# %%
D5.describe()
# Out:
#                   T            HR           PPT            RS             P  \
# count  35040.000000  35040.000000  35040.000000  35040.000000  35040.000000
# mean      15.565594     69.364412      0.045385    183.643950    967.903639
# std        6.663399     16.927146      0.587608    270.450967      6.950804
# min       -2.400000     12.000000      0.000000      0.000000    940.800000
# 25%       10.200000     57.000000      0.000000      0.000000    964.600000
# 50%       15.000000     70.000000      0.000000      5.000000    968.500000
# 75%       20.700000     83.000000      0.000000    321.000000    972.000000
# max       36.600000     99.000000     51.600000   1148.000000    987.700000
#
#                VV10          DV10         VVX10        DVVX10  VV6  DV6  VVX6  \
# count  35029.000000  35029.000000  35028.000000  35028.000000  0.0  0.0   0.0
# mean       4.182129    200.763282      6.788989    203.204608  NaN  NaN   NaN
# ...

# %%
D5["T"]
# Out:
# 0        10.2
# 1         8.7
# 2         7.7
# 3         7.4
# 4         7.3
#          ...
# 35035     6.5
# 35036     7.2
# 35037     6.2
# 35038     5.5
# 35039     5.6
# Name: T, Length: 35040, dtype: float64

# %%
D5["T"].describe()
# Out:
# count    35040.000000
# mean        15.565594
# std          6.663399
# min         -2.400000
# 25%         10.200000
# 50%         15.000000
# 75%         20.700000
# max         36.600000
# Name: T, dtype: float64

# %%
D5['T'].corr(D5['DV10'])
# Out:
# -0.1856486602807352

# %%
# Plot histogram
# %matplotlib inline
D5['T'].plot.hist()

# %%
D5['P'].plot.hist(bins=100)

# %%
D5.plot(x='T', y='P', style='.')

# %%
D5.sample(400).plot(x='T', y='RS', style='.')

# %%
D5.plot(x='T', y='RS', style='.')

# %%
D5['T'].corr(D5['RS'])
# Out:
# 0.45764192948435667

# %%
D5fred = D5[D5['T'] < 0]

# %%
D5fred[D5fred['P']<1000]['T'].plot.hist(bins=40)

# %%
boundaryTemperature = 0
print(len(D5[D5['T']<boundaryTemperature]))
D5[D5['T']<boundaryTemperature].plot(x='DATA', y='T', style='.')
# Out:
# 84

# %%
D5[D5['T']<boundaryTemperature]['T']
# Out:
# 2070    -0.1
# 2072    -0.5
# 2073    -0.6
# 2074    -0.8
# 2075    -0.6
#         ...
# 18013   -0.4
# 18014   -0.6
# 18015   -0.6
# 18016   -0.4
# 18017   -0.1
# Name: T, Length: 84, dtype: float64
